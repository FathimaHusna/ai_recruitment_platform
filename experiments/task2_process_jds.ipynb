# %%
import json
import re
from typing import Dict, List, Optional, Any
from datetime import datetime
import openai
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure, DuplicateKeyError
import logging
from dataclasses import dataclass, asdict
import time
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("OpenAI_API_Key")

# %%
# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
@dataclass
class ProcessedJobDescription:
    """Data class for structured job description"""
    job_id: str
    title: str
    category: str
    company_type: str
    location: str
    employment_type: str
    experience_level: str
    education_requirements: List[str]
    years_of_experience: str
    technical_skills: List[str]
    soft_skills: List[str]
    responsibilities: List[str]
    required_qualifications: List[str]
    preferred_qualifications: List[str]
    benefits: List[str]
    salary_range: str
    job_summary: str
    company_overview: str
    original_description: str
    processed_at: str
    keywords: List[str]
    seniority_level: int  # 1=Entry, 2=Mid, 3=Senior, 4=Lead/Principal

# %%
@dataclass
class ProcessedJobDescription:
    """Data class for structured job description"""
    job_id: str
    title: str
    category: str
    company_type: str
    location: str
    employment_type: str
    experience_level: str
    education_requirements: List[str]
    years_of_experience: str
    technical_skills: List[str]
    soft_skills: List[str]
    responsibilities: List[str]
    required_qualifications: List[str]
    preferred_qualifications: List[str]
    benefits: List[str]
    salary_range: str
    job_summary: str
    company_overview: str
    original_description: str
    processed_at: str
    keywords: List[str]
    seniority_level: int  # 1=Entry, 2=Mid, 3=Senior, 4=Lead/Principal

# %%
class JobDescriptionProcessor:
    def __init__(self, openai_api_key: str, mongo_uri: str = "mongodb://localhost:27017/", 
                 database_name: str = "recruitment_platform"):
        """
        Initialize the Job Description Processor
        
        Args:
            openai_api_key (str): OpenAI API key
            mongo_uri (str): MongoDB connection URI
            database_name (str): Database name
        """
        self.client = openai.OpenAI(api_key=openai_api_key)
        
        # MongoDB setup
        try:
            self.mongo_client = MongoClient(mongo_uri)
            self.db = self.mongo_client[database_name]
            self.collection = self.db.job_descriptions
            
            # Create indexes for better query performance
            self.collection.create_index("job_id", unique=True)
            self.collection.create_index("title")
            self.collection.create_index("category")
            self.collection.create_index("location")
            self.collection.create_index("technical_skills")
            self.collection.create_index("keywords")
            self.collection.create_index("seniority_level")
            
            logger.info("Connected to MongoDB successfully")
            
        except ConnectionFailure as e:
            logger.error(f"Failed to connect to MongoDB: {e}")
            raise

# %%
class JobDescriptionProcessor:
    def __init__(self, openai_api_key: str, mongo_uri: str = "mongodb://localhost:27017/", 
                 database_name: str = "recruitment_platform"):
        """
        Initialize the Job Description Processor
        
        Args:
            openai_api_key (str): OpenAI API key
            mongo_uri (str): MongoDB connection URI
            database_name (str): Database name
        """
        self.client = openai.OpenAI(api_key=openai_api_key)
        
        # MongoDB setup
        try:
            self.mongo_client = MongoClient(mongo_uri)
            self.db = self.mongo_client[database_name]
            self.collection = self.db.job_descriptions
            
            # Create indexes for better query performance
            self.collection.create_index("job_id", unique=True)
            self.collection.create_index("title")
            self.collection.create_index("category")
            self.collection.create_index("location")
            self.collection.create_index("technical_skills")
            self.collection.create_index("keywords")
            self.collection.create_index("seniority_level")
            
            logger.info("Connected to MongoDB successfully")
            
        except ConnectionFailure as e:
            logger.error(f"Failed to connect to MongoDB: {e}")
            raise

    def create_extraction_prompt(self, job_description: str) -> str:
        """
        Create a detailed prompt for extracting structured information from job descriptions
        
        Args:
            job_description (str): Raw job description text
            
        Returns:
            str: Formatted extraction prompt
        """
        prompt = f"""
        Analyze the following job description and extract structured information. 
        Return the information in JSON format with the following exact keys:

        Job Description:
        {job_description}

        Extract and return JSON with these keys:
        {{
            "title": "exact job title",
            "job_summary": "brief 2-3 sentence summary of the role",
            "company_overview": "company description if available",
            "responsibilities": ["list", "of", "key", "responsibilities"],
            "education_requirements": ["degree requirements", "certifications"],
            "years_of_experience": "X-Y years or specific requirement",
            "technical_skills": ["specific", "technical", "skills", "tools", "technologies"],
            "soft_skills": ["communication", "leadership", "teamwork", "etc"],
            "required_qualifications": ["must", "have", "qualifications"],
            "preferred_qualifications": ["nice", "to", "have", "qualifications"],
            "benefits": ["list", "of", "benefits", "mentioned"],
            "salary_range": "salary range if mentioned or 'Not specified'",
            "employment_type": "Full-time, Part-time, Contract, etc.",
            "keywords": ["relevant", "keywords", "for", "search", "matching"]
        }}

        Guidelines:
        - Extract only information that is explicitly mentioned
        - For technical_skills, include programming languages, frameworks, tools, databases, etc.
        - For keywords, include important terms that would help in job matching
        - Keep lists concise but comprehensive
        - If information is not available, use empty array [] or "Not specified"
        - Return only valid JSON, no additional text
        """
        return prompt

    def extract_structured_data(self, raw_jd: Dict) -> Optional[ProcessedJobDescription]:
        """
        Extract structured data from a raw job description using LLM
        
        Args:
            raw_jd (Dict): Raw job description data
            
        Returns:
            Optional[ProcessedJobDescription]: Processed job description or None if failed
        """
        try:
            # Create extraction prompt
            full_description = raw_jd.get('full_description', '')
            prompt = self.create_extraction_prompt(full_description)
            
            # Call OpenAI API
            response = self.client.chat.completions.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "You are an expert HR data analyst. Extract structured information from job descriptions and return only valid JSON."},
                    {"role": "user", "content": prompt}
                ],
                max_tokens=1500,
                temperature=0.3  # Lower temperature for more consistent extraction
            )
            
            # Parse the response
            extracted_text = response.choices[0].message.content.strip()
            
            # Clean the response to ensure valid JSON
            extracted_text = self._clean_json_response(extracted_text)
            
            # Parse JSON
            extracted_data = json.loads(extracted_text)
            
            # Map seniority level
            seniority_level = self._map_seniority_level(raw_jd.get('experience_level', ''))
            
            # Create ProcessedJobDescription object
            processed_jd = ProcessedJobDescription(
                job_id=raw_jd.get('id', f"JD_{int(time.time())}"),
                title=extracted_data.get('title', raw_jd.get('title', 'Unknown')),
                category=raw_jd.get('category', 'Unknown'),
                company_type=raw_jd.get('company_type', 'Unknown'),
                location=raw_jd.get('location', 'Unknown'),
                employment_type=extracted_data.get('employment_type', 'Full-time'),
                experience_level=raw_jd.get('experience_level', 'Not specified'),
                education_requirements=extracted_data.get('education_requirements', []),
                years_of_experience=extracted_data.get('years_of_experience', 'Not specified'),
                technical_skills=extracted_data.get('technical_skills', []),
                soft_skills=extracted_data.get('soft_skills', []),
                responsibilities=extracted_data.get('responsibilities', []),
                required_qualifications=extracted_data.get('required_qualifications', []),
                preferred_qualifications=extracted_data.get('preferred_qualifications', []),
                benefits=extracted_data.get('benefits', []),
                salary_range=extracted_data.get('salary_range', 'Not specified'),
                job_summary=extracted_data.get('job_summary', ''),
                company_overview=extracted_data.get('company_overview', ''),
                original_description=full_description,
                processed_at=datetime.now().isoformat(),
                keywords=extracted_data.get('keywords', []),
                seniority_level=seniority_level
            )
            
            return processed_jd
            
        except json.JSONDecodeError as e:
            logger.error(f"JSON parsing error for job {raw_jd.get('id', 'unknown')}: {e}")
            return None
        except Exception as e:
            logger.error(f"Error processing job {raw_jd.get('id', 'unknown')}: {e}")
            return None

    def _clean_json_response(self, response_text: str) -> str:
        """
        Clean the LLM response to ensure valid JSON
        
        Args:
            response_text (str): Raw response from LLM
            
        Returns:
            str: Cleaned JSON string
        """
        # Remove any text before the first {
        start_idx = response_text.find('{')
        if start_idx != -1:
            response_text = response_text[start_idx:]
        
        # Remove any text after the last }
        end_idx = response_text.rfind('}')
        if end_idx != -1:
            response_text = response_text[:end_idx + 1]
        
        return response_text

    def _map_seniority_level(self, experience_level: str) -> int:
        """
        Map experience level to numeric seniority level
        
        Args:
            experience_level (str): Experience level string
            
        Returns:
            int: Numeric seniority level
        """
        experience_level = experience_level.lower()
        if 'entry' in experience_level or 'junior' in experience_level:
            return 1
        elif 'mid' in experience_level:
            return 2
        elif 'senior' in experience_level:
            return 3
        elif 'lead' in experience_level or 'principal' in experience_level:
            return 4
        else:
            return 2  # Default to mid-level

    def store_in_mongodb(self, processed_jd: ProcessedJobDescription) -> bool:
        """
        Store processed job description in MongoDB
        
        Args:
            processed_jd (ProcessedJobDescription): Processed job description
            
        Returns:
            bool: True if successful, False otherwise
        """
        try:
            # Convert to dictionary
            jd_dict = asdict(processed_jd)
            
            # Insert or update in MongoDB
            result = self.collection.replace_one(
                {"job_id": processed_jd.job_id},
                jd_dict,
                upsert=True
            )
            
            if result.upserted_id or result.modified_count > 0:
                logger.info(f"Successfully stored job: {processed_jd.job_id}")
                return True
            else:
                logger.warning(f"No changes made for job: {processed_jd.job_id}")
                return False
                
        except Exception as e:
            logger.error(f"Error storing job {processed_jd.job_id} in MongoDB: {e}")
            return False

    def process_all_job_descriptions(self, input_file: str = "job_descriptions_dataset.json") -> Dict[str, Any]:
        """
        Process all job descriptions from the input file
        
        Args:
            input_file (str): Path to the job descriptions JSON file
            
        Returns:
            Dict[str, Any]: Processing results summary
        """
        try:
            # Load job descriptions
            with open(input_file, 'r', encoding='utf-8') as f:
                raw_job_descriptions = json.load(f)
            
            logger.info(f"Loaded {len(raw_job_descriptions)} job descriptions")
            
            # Processing counters
            successful_processed = 0
            failed_processed = 0
            successful_stored = 0
            failed_stored = 0
            
            # Process each job description
            for i, raw_jd in enumerate(raw_job_descriptions, 1):
                logger.info(f"Processing job {i}/{len(raw_job_descriptions)}: {raw_jd.get('title', 'Unknown')}")
                
                # Extract structured data
                processed_jd = self.extract_structured_data(raw_jd)
                
                if processed_jd:
                    successful_processed += 1
                    
                    # Store in MongoDB
                    if self.store_in_mongodb(processed_jd):
                        successful_stored += 1
                    else:
                        failed_stored += 1
                else:
                    failed_processed += 1
                    logger.error(f"Failed to process job: {raw_jd.get('id', 'unknown')}")
                
                # Add delay to avoid rate limiting
                time.sleep(1)
            
            # Generate summary
            summary = {
                "total_jobs": len(raw_job_descriptions),
                "successful_processed": successful_processed,
                "failed_processed": failed_processed,
                "successful_stored": successful_stored,
                "failed_stored": failed_stored,
                "processing_date": datetime.now().isoformat(),
                "mongodb_collection": self.collection.name,
                "mongodb_database": self.db.name
            }
            
            logger.info(f"Processing complete! Summary: {summary}")
            return summary
            
        except FileNotFoundError:
            logger.error(f"Input file {input_file} not found")
            raise
        except Exception as e:
            logger.error(f"Error processing job descriptions: {e}")
            raise

    def get_collection_stats(self) -> Dict[str, Any]:
        """
        Get statistics about the stored job descriptions
        
        Returns:
            Dict[str, Any]: Collection statistics
        """
        try:
            total_jobs = self.collection.count_documents({})
            
            # Get category distribution
            category_stats = list(self.collection.aggregate([
                {"$group": {"_id": "$category", "count": {"$sum": 1}}},
                {"$sort": {"count": -1}}
            ]))
            
            # Get location distribution
            location_stats = list(self.collection.aggregate([
                {"$group": {"_id": "$location", "count": {"$sum": 1}}},
                {"$sort": {"count": -1}}
            ]))
            
            # Get seniority level distribution
            seniority_stats = list(self.collection.aggregate([
                {"$group": {"_id": "$seniority_level", "count": {"$sum": 1}}},
                {"$sort": {"_id": 1}}
            ]))
            
            # Get top technical skills
            top_skills = list(self.collection.aggregate([
                {"$unwind": "$technical_skills"},
                {"$group": {"_id": "$technical_skills", "count": {"$sum": 1}}},
                {"$sort": {"count": -1}},
                {"$limit": 20}
            ]))
            
            stats = {
                "total_jobs": total_jobs,
                "category_distribution": {item["_id"]: item["count"] for item in category_stats},
                "location_distribution": {item["_id"]: item["count"] for item in location_stats},
                "seniority_distribution": {item["_id"]: item["count"] for item in seniority_stats},
                "top_technical_skills": {item["_id"]: item["count"] for item in top_skills},
                "last_updated": datetime.now().isoformat()
            }
            
            return stats
            
        except Exception as e:
            logger.error(f"Error getting collection stats: {e}")
            return {}

    def search_jobs(self, query: Dict[str, Any], limit: int = 10) -> List[Dict]:
        """
        Search jobs in the MongoDB collection
        
        Args:
            query (Dict[str, Any]): MongoDB query
            limit (int): Maximum number of results
            
        Returns:
            List[Dict]: Search results
        """
        try:
            results = list(self.collection.find(query, {"_id": 0}).limit(limit))
            return results
        except Exception as e:
            logger.error(f"Error searching jobs: {e}")
            return []

    def close_connection(self):
        """Close MongoDB connection"""
        if hasattr(self, 'mongo_client'):
            self.mongo_client.close()
            logger.info("MongoDB connection closed")

# %%
load_dotenv()
MONGO_URI = os.getenv("MONGO_URI") 
print(MONGO_URI)
# Out:
# mongodb+srv://nusrathamtha:sfupuHmba8xgqZdy@cluster0.rosecne.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0

# %%
MONGO_URI

# %%
from pymongo import MongoClient
MONGO_URI = os.getenv("MONGO_URI") 

try:
    client = MongoClient(MONGO_URI, serverSelectionTimeoutMS=5000)
    client.admin.command("ping")
    print("MongoDB Atlas connection successful")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# MongoDB Atlas connection successful

# %%
def main():
    """
    Main function to run the job description processor
    """
    # Configuration
    OPENAI_API_KEY = os.getenv("OpenAI_API_Key")  # Replace with your actual API key
    MONGO_URI = os.getenv("MONGO_URI")  # Update if using cloud MongoDB
    DATABASE_NAME = "recruitment_platform"
    INPUT_FILE = "job_descriptions_dataset.json"
    
    # if OPENAI_API_KEY == os.getenv("OpenAI_API_Key"):
    #     print("⚠️  Please replace 'your-openai-api-key-here' with your actual OpenAI API key")
    #     return
    
    try:
        # Initialize processor
        processor = JobDescriptionProcessor(
            openai_api_key=OPENAI_API_KEY,
            mongo_uri=MONGO_URI,
            database_name=DATABASE_NAME
        )
        
        # Process all job descriptions
        print("Starting job description processing...")
        summary = processor.process_all_job_descriptions(INPUT_FILE)
        
        # Save processing summary
        with open("processing_summary.json", 'w', encoding='utf-8') as f:
            json.dump(summary, f, indent=2, ensure_ascii=False)
        
        # Get and save collection statistics
        stats = processor.get_collection_stats()
        with open("collection_stats.json", 'w', encoding='utf-8') as f:
            json.dump(stats, f, indent=2, ensure_ascii=False)
        
        # Print summary
        print("\n" + "="*60)
        print("PROCESSING SUMMARY")
        print("="*60)
        print(f"Total Jobs: {summary['total_jobs']}")
        print(f"Successfully Processed: {summary['successful_processed']}")
        print(f"Successfully Stored: {summary['successful_stored']}")
        print(f"Failed Processing: {summary['failed_processed']}")
        print(f"Failed Storage: {summary['failed_stored']}")
        
        print("\n" + "="*60)
        print("COLLECTION STATISTICS")
        print("="*60)
        print(f"Total Jobs in Database: {stats['total_jobs']}")
        print("\nTop Categories:")
        for category, count in list(stats['category_distribution'].items())[:5]:
            print(f"  {category}: {count}")
        
        print("\nTop Technical Skills:")
        for skill, count in list(stats['top_technical_skills'].items())[:10]:
            print(f"  {skill}: {count}")
        
        print(f"\nFiles generated:")
        print(f"  - processing_summary.json")
        print(f"  - collection_stats.json")
        
        # Close connection
        processor.close_connection()
        
    except Exception as e:
        logger.error(f"Error in main execution: {e}")
        raise

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Connected to MongoDB successfully
# INFO:__main__:Loaded 200 job descriptions
# INFO:__main__:Processing job 1/200: DevOps Engineer
# Starting job description processing...
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8986_1753437955
# INFO:__main__:Processing job 2/200: Backend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7363_1753437962
# INFO:__main__:Processing job 3/200: AI/ML Consultant
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2589_1753437969
# INFO:__main__:Processing job 4/200: Agile Coach
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1178_1753437976
# INFO:__main__:Processing job 5/200: QA Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4336_1753437984
# INFO:__main__:Processing job 6/200: Computer Vision Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4943_1753437991
# INFO:__main__:Processing job 7/200: Infrastructure Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6342_1753437996
# INFO:__main__:Processing job 8/200: Business Intelligence Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5414_1753438002
# INFO:__main__:Processing job 9/200: Release Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4338_1753438012
# INFO:__main__:Processing job 10/200: Data Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8892_1753438027
# INFO:__main__:Processing job 11/200: Senior QA Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4017_1753438043
# INFO:__main__:Processing job 12/200: Platform Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3179_1753438050
# INFO:__main__:Processing job 13/200: Data Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5660_1753438058
# INFO:__main__:Processing job 14/200: MLOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3198_1753438064
# INFO:__main__:Processing job 15/200: QA Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8551_1753438068
# INFO:__main__:Processing job 16/200: Senior QA Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2863_1753438075
# INFO:__main__:Processing job 17/200: QA Lead
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2440_1753438079
# INFO:__main__:Processing job 18/200: Product Owner
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4364_1753438085
# INFO:__main__:Processing job 19/200: Senior Backend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5063_1753438091
# INFO:__main__:Processing job 20/200: Data Visualization Expert
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4821_1753438098
# INFO:__main__:Processing job 21/200: NLP Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8793_1753438114
# INFO:__main__:Processing job 22/200: DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4288_1753438122
# INFO:__main__:Processing job 23/200: Program Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3467_1753438126
# INFO:__main__:Processing job 24/200: QA Lead
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4683_1753438132
# INFO:__main__:Processing job 25/200: Program Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7366_1753438140
# INFO:__main__:Processing job 26/200: QA Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9619_1753438149
# INFO:__main__:Processing job 27/200: Technical Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6090_1753438156
# INFO:__main__:Processing job 28/200: Deep Learning Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7907_1753438164
# INFO:__main__:Processing job 29/200: DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2267_1753438171
# INFO:__main__:Processing job 30/200: MLOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6044_1753438180
# INFO:__main__:Processing job 31/200: Computer Vision Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9643_1753438196
# INFO:__main__:Processing job 32/200: Senior ML Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2371_1753438205
# INFO:__main__:Processing job 33/200: Manual Testing Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8986_1753438211
# INFO:__main__:Processing job 34/200: Agile Coach
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4691_1753438217
# INFO:__main__:Processing job 35/200: Business Intelligence Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9193_1753438226
# INFO:__main__:Processing job 36/200: Product Owner
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9196_1753438236
# INFO:__main__:Processing job 37/200: Product Owner
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3356_1753438241
# INFO:__main__:Processing job 38/200: Business Intelligence Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3908_1753438247
# INFO:__main__:Processing job 39/200: Deep Learning Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9993_1753438253
# INFO:__main__:Processing job 40/200: NLP Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8156_1753438264
# INFO:__main__:Processing job 41/200: NLP Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1465_1753438282
# INFO:__main__:Processing job 42/200: Market Research Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4595_1753438287
# INFO:__main__:Processing job 43/200: DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3022_1753438296
# INFO:__main__:Processing job 44/200: Release Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6823_1753438302
# INFO:__main__:Processing job 45/200: Lead Full Stack Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8496_1753438308
# INFO:__main__:Processing job 46/200: Senior Software Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2914_1753438318
# INFO:__main__:Processing job 47/200: Infrastructure Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1114_1753438326
# INFO:__main__:Processing job 48/200: Data Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9689_1753438334
# INFO:__main__:Processing job 49/200: Market Research Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3375_1753438340
# INFO:__main__:Processing job 50/200: Senior ML Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1848_1753438349
# INFO:__main__:Processing job 51/200: Product Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3161_1753438364
# INFO:__main__:Processing job 52/200: Frontend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2011_1753438370
# INFO:__main__:Processing job 53/200: Senior QA Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8267_1753438377
# INFO:__main__:Processing job 54/200: DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8955_1753438385
# INFO:__main__:Processing job 55/200: MLOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9655_1753438391
# INFO:__main__:Processing job 56/200: Software Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3882_1753438400
# INFO:__main__:Processing job 57/200: Lead Full Stack Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3203_1753438410
# INFO:__main__:Processing job 58/200: Senior ML Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8589_1753438420
# INFO:__main__:Processing job 59/200: Data Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2543_1753438425
# INFO:__main__:Processing job 60/200: Cloud Architect
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3960_1753438432
# INFO:__main__:Processing job 61/200: Technical Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5410_1753438447
# INFO:__main__:Processing job 62/200: Business Intelligence Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2275_1753438453
# INFO:__main__:Processing job 63/200: Senior Frontend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2501_1753438463
# INFO:__main__:Processing job 64/200: Database Administrator
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2437_1753438468
# INFO:__main__:Processing job 65/200: Agile Coach
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1167_1753438476
# INFO:__main__:Processing job 66/200: NLP Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8826_1753438482
# INFO:__main__:Processing job 67/200: Senior QA Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9178_1753438492
# INFO:__main__:Processing job 68/200: Lead Full Stack Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6310_1753438502
# INFO:__main__:Processing job 69/200: Technical Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5228_1753438508
# INFO:__main__:Processing job 70/200: AI/ML Consultant
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9323_1753438516
# INFO:__main__:Processing job 71/200: Manual Testing Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6158_1753438532
# INFO:__main__:Processing job 72/200: Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7635_1753438538
# INFO:__main__:Processing job 73/200: AI Researcher
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1719_1753438544
# INFO:__main__:Processing job 74/200: Test Architect
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1269_1753438549
# INFO:__main__:Processing job 75/200: QA Lead
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1684_1753438558
# INFO:__main__:Processing job 76/200: Frontend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6482_1753438565
# INFO:__main__:Processing job 77/200: NLP Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9158_1753438573
# INFO:__main__:Processing job 78/200: Senior QA Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3087_1753438582
# INFO:__main__:Processing job 79/200: Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5042_1753438588
# INFO:__main__:Processing job 80/200: Manual Testing Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1521_1753438595
# INFO:__main__:Processing job 81/200: Senior Software Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6816_1753438610
# INFO:__main__:Processing job 82/200: Software Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1411_1753438620
# INFO:__main__:Processing job 83/200: Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1443_1753438626
# INFO:__main__:Processing job 84/200: Agile Coach
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9833_1753438631
# INFO:__main__:Processing job 85/200: Senior DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5933_1753438638
# INFO:__main__:Processing job 86/200: Senior Software Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2712_1753438644
# INFO:__main__:Processing job 87/200: DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3950_1753438650
# INFO:__main__:Processing job 88/200: Infrastructure Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2339_1753438656
# INFO:__main__:Processing job 89/200: Scrum Master
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1989_1753438665
# INFO:__main__:Processing job 90/200: Machine Learning Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1224_1753438673
# INFO:__main__:Processing job 91/200: Data Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4249_1753438688
# INFO:__main__:Processing job 92/200: QA Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2634_1753438695
# INFO:__main__:Processing job 93/200: Scrum Master
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9315_1753438703
# INFO:__main__:Processing job 94/200: Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9171_1753438709
# INFO:__main__:Processing job 95/200: Junior Data Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9648_1753438717
# INFO:__main__:Processing job 96/200: Test Architect
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1543_1753438723
# INFO:__main__:Processing job 97/200: Senior Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9826_1753438729
# INFO:__main__:Processing job 98/200: Scrum Master
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3873_1753438735
# INFO:__main__:Processing job 99/200: Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7856_1753438741
# INFO:__main__:Processing job 100/200: Data Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2193_1753438751
# INFO:__main__:Processing job 101/200: MLOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4040_1753438768
# INFO:__main__:Processing job 102/200: Cloud Architect
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2649_1753438774
# INFO:__main__:Processing job 103/200: Infrastructure Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6217_1753438782
# INFO:__main__:Processing job 104/200: Product Owner
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6447_1753438788
# INFO:__main__:Processing job 105/200: QA Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3518_1753438796
# INFO:__main__:Processing job 106/200: Senior DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8969_1753438802
# INFO:__main__:Processing job 107/200: Technical Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2362_1753438808
# INFO:__main__:Processing job 108/200: QA Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9626_1753438815
# INFO:__main__:Processing job 109/200: QA Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3687_1753438822
# INFO:__main__:Processing job 110/200: MLOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7269_1753438831
# INFO:__main__:Processing job 111/200: Platform Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6512_1753438848
# INFO:__main__:Processing job 112/200: Product Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3538_1753438856
# INFO:__main__:Processing job 113/200: AI Researcher
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9196_1753438865
# INFO:__main__:Processing job 114/200: Deep Learning Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8431_1753438873
# INFO:__main__:Processing job 115/200: BI Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4659_1753438877
# INFO:__main__:Processing job 116/200: Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7623_1753438883
# INFO:__main__:Processing job 117/200: Principal Data Scientist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4108_1753438889
# INFO:__main__:Processing job 118/200: Data Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4869_1753438898
# INFO:__main__:Processing job 119/200: Senior DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6864_1753438904
# INFO:__main__:Processing job 120/200: Market Research Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3322_1753438909
# INFO:__main__:Processing job 121/200: Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7714_1753438927
# INFO:__main__:Processing job 122/200: Product Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7511_1753438932
# INFO:__main__:Processing job 123/200: Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2243_1753438941
# INFO:__main__:Processing job 124/200: Principal Data Scientist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9264_1753438947
# INFO:__main__:Processing job 125/200: Data Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7486_1753438953
# INFO:__main__:Processing job 126/200: Product Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2720_1753438959
# INFO:__main__:Processing job 127/200: Manual Testing Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1822_1753438963
# INFO:__main__:Processing job 128/200: AI Researcher
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6253_1753438969
# INFO:__main__:Processing job 129/200: Scrum Master
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7198_1753438977
# INFO:__main__:Processing job 130/200: Data Visualization Expert
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7514_1753438983
# INFO:__main__:Processing job 131/200: Cloud Architect
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5135_1753438999
# INFO:__main__:Processing job 132/200: Full Stack Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9457_1753439005
# INFO:__main__:Processing job 133/200: Manual Testing Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4323_1753439010
# INFO:__main__:Processing job 134/200: Lead Full Stack Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1642_1753439018
# INFO:__main__:Processing job 135/200: Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5891_1753439024
# INFO:__main__:Processing job 136/200: Program Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9482_1753439032
# INFO:__main__:Processing job 137/200: QA Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9566_1753439038
# INFO:__main__:Processing job 138/200: Computer Vision Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3271_1753439043
# INFO:__main__:Processing job 139/200: Business Intelligence Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6531_1753439051
# INFO:__main__:Processing job 140/200: Reporting Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8961_1753439057
# INFO:__main__:Processing job 141/200: AI/ML Consultant
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3637_1753439074
# INFO:__main__:Processing job 142/200: Senior DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7249_1753439080
# INFO:__main__:Processing job 143/200: Data Scientist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9303_1753439092
# INFO:__main__:Processing job 144/200: Junior Data Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1671_1753439097
# INFO:__main__:Processing job 145/200: Senior Software Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5140_1753439102
# INFO:__main__:Processing job 146/200: Test Architect
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7753_1753439108
# INFO:__main__:Processing job 147/200: Test Automation Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1659_1753439114
# INFO:__main__:Processing job 148/200: Manual Testing Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1015_1753439120
# INFO:__main__:Processing job 149/200: Senior ML Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7086_1753439126
# INFO:__main__:Processing job 150/200: Software Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6968_1753439132
# INFO:__main__:Processing job 151/200: Performance Test Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7131_1753439147
# INFO:__main__:Processing job 152/200: Product Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7016_1753439153
# INFO:__main__:Processing job 153/200: Senior Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7138_1753439160
# INFO:__main__:Processing job 154/200: Senior Frontend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8279_1753439167
# INFO:__main__:Processing job 155/200: QA Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8728_1753439175
# INFO:__main__:Processing job 156/200: Lead Full Stack Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5856_1753439181
# INFO:__main__:Processing job 157/200: Site Reliability Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6485_1753439187
# INFO:__main__:Processing job 158/200: Lead Full Stack Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3719_1753439194
# INFO:__main__:Processing job 159/200: Data Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7604_1753439199
# INFO:__main__:Processing job 160/200: QA Lead
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4118_1753439205
# INFO:__main__:Processing job 161/200: Business Intelligence Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2095_1753439221
# INFO:__main__:Processing job 162/200: Senior Backend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7783_1753439231
# INFO:__main__:Processing job 163/200: Junior Data Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9000_1753439240
# INFO:__main__:Processing job 164/200: Senior Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4342_1753439246
# INFO:__main__:Processing job 165/200: Senior Frontend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7856_1753439252
# INFO:__main__:Processing job 166/200: Frontend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6111_1753439259
# INFO:__main__:Processing job 167/200: Test Automation Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5792_1753439268
# INFO:__main__:Processing job 168/200: Technical Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6563_1753439274
# INFO:__main__:Processing job 169/200: Lead Full Stack Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4897_1753439285
# INFO:__main__:Processing job 170/200: Program Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1688_1753439295
# INFO:__main__:Processing job 171/200: Senior Data Scientist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2662_1753439310
# INFO:__main__:Processing job 172/200: Site Reliability Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8736_1753439321
# INFO:__main__:Processing job 173/200: Senior Software Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2906_1753439328
# INFO:__main__:Processing job 174/200: Senior Business Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6072_1753439335
# INFO:__main__:Processing job 175/200: Senior QA Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3177_1753439340
# INFO:__main__:Processing job 176/200: Technical Project Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6913_1753439348
# INFO:__main__:Processing job 177/200: Test Automation Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4602_1753439354
# INFO:__main__:Processing job 178/200: NLP Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2259_1753439361
# INFO:__main__:Processing job 179/200: Product Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8318_1753439368
# INFO:__main__:Processing job 180/200: Data Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1078_1753439373
# INFO:__main__:Processing job 181/200: Senior Software Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1235_1753439393
# INFO:__main__:Processing job 182/200: Business Intelligence Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_3058_1753439398
# INFO:__main__:Processing job 183/200: DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1953_1753439403
# INFO:__main__:Processing job 184/200: Computer Vision Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2324_1753439410
# INFO:__main__:Processing job 185/200: DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6517_1753439416
# INFO:__main__:Processing job 186/200: Analytics Consultant
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5760_1753439422
# INFO:__main__:Processing job 187/200: Release Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6371_1753439428
# INFO:__main__:Processing job 188/200: Senior Data Scientist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8219_1753439434
# INFO:__main__:Processing job 189/200: AI/ML Consultant
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_4895_1753439443
# INFO:__main__:Processing job 190/200: Reporting Analyst
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7661_1753439452
# INFO:__main__:Processing job 191/200: Analytics Consultant
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9630_1753439469
# INFO:__main__:Processing job 192/200: Frontend Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9280_1753439478
# INFO:__main__:Processing job 193/200: QA Lead
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1338_1753439488
# INFO:__main__:Processing job 194/200: Program Manager
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_9735_1753439494
# INFO:__main__:Processing job 195/200: Release Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_7259_1753439501
# INFO:__main__:Processing job 196/200: MLOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_6099_1753439506
# INFO:__main__:Processing job 197/200: Senior DevOps Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_8824_1753439516
# INFO:__main__:Processing job 198/200: NLP Specialist
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_5703_1753439523
# INFO:__main__:Processing job 199/200: Release Engineer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_2032_1753439534
# INFO:__main__:Processing job 200/200: Business Intelligence Developer
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:__main__:Successfully stored job: JD_1799_1753439540
# INFO:__main__:Processing complete! Summary: {'total_jobs': 200, 'successful_processed': 200, 'failed_processed': 0, 'successful_stored': 200, 'failed_stored': 0, 'processing_date': '2025-07-25T18:12:35.151575', 'mongodb_collection': 'job_descriptions', 'mongodb_database': 'recruitment_platform'}
# ============================================================
# PROCESSING SUMMARY
# ============================================================
# Total Jobs: 200
# Successfully Processed: 200
# Successfully Stored: 200
# Failed Processing: 0
# Failed Storage: 0
#
# ============================================================
# COLLECTION STATISTICS
# ============================================================
# Total Jobs in Database: 200
#
# Top Categories:
#   Project Management: 41
#   Quality Assurance: 33
#   Machine Learning: 32
#   DevOps: 29
#   Software Engineering: 27
#
# Top Technical Skills:
#   Python: 85
#   SQL: 33
#   Java: 29
#   TensorFlow: 28
#   R: 24
#   Selenium: 23
#   Tableau: 21
#   AWS: 20
#   Kubernetes: 18
#   Docker: 18
#
# Files generated:
#   - processing_summary.json
#   - collection_stats.json
# INFO:__main__:MongoDB connection closed
